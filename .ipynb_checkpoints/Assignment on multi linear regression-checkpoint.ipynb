# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score

# %%
#Startups problem
startups_df=pd.read_csv('50_Startups.csv')
startups_df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
startups_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
sns.heatmap(startups_df.corr())
# Out:
# <AxesSubplot:>

# %%
startups_df.corr()
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000

# %%
scaler=StandardScaler()
standard=scaler.fit_transform(startups_df.iloc[:,0:3])

x=standard
y=startups_df.iloc[:,-1]

X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.3,random_state=0)

# %%
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
ypred=model.predict(X_test)
ypred
# Out:
# array([104054.44293869, 132719.3459701 , 133640.26830949,  72294.76911458,
#        179685.62227843, 114508.97572031,  66305.23069863,  98297.69326565,
#        114277.91894933, 169112.36095691,  96257.40152149,  87916.97242208,
#        110687.33942598,  90670.8337806 , 127780.63539583])

# %%
from sklearn.metrics import r2_score

print('Test Accuracy',r2_score(y_test,ypred))

ypred_train=model.predict(X_train)
print('Training Accuracy',r2_score(y_train,ypred_train))
# Out:
# Test Accuracy 0.9355188337118218
# Training Accuracy 0.9515391457049143

# %%
new_df=pd.DataFrame({'y-predict':ypred,'y-actual':y_test,'Difference':y_test-ypred})
new_df
# Out:
#         y-predict   y-actual    Difference
# 28  104054.442939  103282.38   -772.062939
# 11  132719.345970  144259.40  11540.054030
# 10  133640.268309  146121.95  12481.681691
# 41   72294.769115   77798.83   5504.060885
# 2   179685.622278  191050.39  11364.767722
# 27  114508.975720  105008.31  -9500.665720
# 38   66305.230699   81229.06  14923.829301
# 31   98297.693266   97483.56   -814.133266
# 22  114277.918949  110352.25  -3925.668949
# 4   169112.360957  166187.94  -2924.420957
# 33   96257.401521   96778.92    521.518479
# 35   87916.972422   96479.51   8562.537578
# 26  110687.339426  105733.54  -4953.799426
# 34   90670.833781   96712.80   6041.966219
# 18  127780.635396  124266.90  -3513.735396

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
sns.regplot(y_test,ypred)
plt.xlabel('Actual values')
plt.ylabel('predected values')
plt.suptitle('regression plot')
plt.legend()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
overallpred=model.predict(x)

# %%
p=pd.Series(overallpred)
p.head()
# Out:
# 0    192214.729083
# 1    189615.912205
# 2    179685.622278
# 3    172286.723148
# 4    169112.360957
# dtype: float64

# %%
new_df=pd.DataFrame({'y-predict':p,'y-actual':y,'Difference':y-p})
new_df.head()
# Out:
#        y-predict   y-actual    Difference
# 0  192214.729083  192261.83     47.100917
# 1  189615.912205  191792.06   2176.147795
# 2  179685.622278  191050.39  11364.767722
# 3  172286.723148  182901.99  10615.266852
# 4  169112.360957  166187.94  -2924.420957

# %%
startups_df['Predicted values']=np.round(p,3)
startups_df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit  \
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94
#
#    Predicted values
# 0        192214.729
# 1        189615.912
# 2        179685.622
# 3        172286.723
# 4        169112.361

# %%
#lets plot the overall prediction

# %%
sns.regplot(y,p)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Profit'>

# %%
#Toyota corolla

# %%
carprice_df=pd.read_csv('ToyotaCorolla.csv')
carprice_df.head()
# Out:
#    Id  Price  Age_08_04  Mfg_Month  Mfg_Year     KM Fuel_Type  HP  Met_Color  \
# 0   1  13500         23         10      2002  46986    Diesel  90          1
# 1   2  13750         23         10      2002  72937    Diesel  90          1
# 2   3  13950         24          9      2002  41711    Diesel  90          1
# 3   4  14950         26          7      2002  48000    Diesel  90          0
# 4   5  13750         30          3      2002  38500    Diesel  90          0
#
#     Color  Automatic    cc  Doors  Cylinders  Gears  Quarterly_Tax  Weight
# 0    Blue          0  2000      3          4      5            210    1165
# 1  Silver          0  2000      3          4      5            210    1165
# 2    Blue          0  2000      3          4      5            210    1165
# 3   Black          0  2000      3          4      5            210    1165
# 4   Black          0  2000      3          4      5            210    1170

# %%
carprice_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1436 non-null   int64
#  1   Price          1436 non-null   int64
#  2   Age_08_04      1436 non-null   int64
#  3   Mfg_Month      1436 non-null   int64
#  4   Mfg_Year       1436 non-null   int64
#  5   KM             1436 non-null   int64
#  6   Fuel_Type      1436 non-null   object
#  7   HP             1436 non-null   int64
#  8   Met_Color      1436 non-null   int64
#  9   Color          1436 non-null   object
#  10  Automatic      1436 non-null   int64
#  11  cc             1436 non-null   int64
#  12  Doors          1436 non-null   int64
#  13  Cylinders      1436 non-null   int64
#  14  Gears          1436 non-null   int64
#  15  Quarterly_Tax  1436 non-null   int64
#  16  Weight         1436 non-null   int64
# dtypes: int64(15), object(2)
# memory usage: 190.8+ KB

# %%
y=carprice_df.iloc[:,1]
x=carprice_df.iloc[:,[2,5,7,11,12,14,15,16]]

# %%
x.head()
# Out:
#    Age_08_04     KM  HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0         23  46986  90  2000      3      5            210    1165
# 1         23  72937  90  2000      3      5            210    1165
# 2         24  41711  90  2000      3      5            210    1165
# 3         26  48000  90  2000      3      5            210    1165
# 4         30  38500  90  2000      3      5            210    1170

# %%
y.head()
# Out:
# 0    13500
# 1    13750
# 2    13950
# 3    14950
# 4    13750
# Name: Price, dtype: int64

# %%
x.corr()
# Out:
#                Age_08_04        KM        HP        cc     Doors     Gears  \
# Age_08_04       1.000000  0.505672 -0.156622 -0.098084 -0.148359 -0.005364
# KM              0.505672  1.000000 -0.333538  0.102683 -0.036197  0.015023
# HP             -0.156622 -0.333538  1.000000  0.035856  0.092424  0.209477
# cc             -0.098084  0.102683  0.035856  1.000000  0.079903  0.014629
# Doors          -0.148359 -0.036197  0.092424  0.079903  1.000000 -0.160141
# Gears          -0.005364  0.015023  0.209477  0.014629 -0.160141  1.000000
# Quarterly_Tax  -0.198431  0.278165 -0.298432  0.306996  0.109363 -0.005452
# Weight         -0.470253 -0.028598  0.089614  0.335637  0.302618  0.020613
#
#                Quarterly_Tax    Weight
# Age_08_04          -0.198431 -0.470253
# KM                  0.278165 -0.028598
# HP                 -0.298432  0.089614
# cc                  0.306996  0.335637
# Doors               0.109363  0.302618
# Gears              -0.005452  0.020613
# Quarterly_Tax       1.000000  0.626134
# Weight              0.626134  1.000000

# %%
sns.heatmap(x.corr())
# Out:
# <AxesSubplot:>

# %%
x=StandardScaler().fit_transform(x)

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.3,random_state=0)

# %%
model=LinearRegression().fit(X_train,y_train)
#predicting using xtest and finding test accuracy
yprdct=model.predict(X_test)
yprdct
# Out:
# array([ 8217.90123614, 10406.47736728, 12920.77230228,  7700.70618906,
#        10456.75601504,  9573.25969022,  6220.06668058, 16321.32575368,
#        11279.2041531 , 10353.31118724,  6913.71088067, 11126.1790467 ,
#        11747.03252179,  9741.42767561,  7407.9011322 , 16210.18917256,
#        11106.71261343,  7756.13384775, 12735.3650973 ,  8726.71930256,
#         6703.77688542,  6091.50127   , 11621.3203889 , 12490.52206021,
#        19040.43685272,  7794.35951579, 13963.8531286 ,  5705.50370915,
#         9226.48866462,  7861.3081688 , 10684.42377462,  7708.35324753,
#        16128.80972058,  7201.78647326, 11082.80138567, 12737.18599106,
#         9847.06450909, 12132.22021172,  9881.44765846,  8998.69970344,
#         8724.85105747, 10551.24727474,  9938.10148021, 17172.37477917,
#        10890.60210792,  7077.99886815,  9531.02807285,  7556.93986147,
#         8485.48728779,  8747.28253177, 19320.01035119,  8361.19781742,
#         7116.66467257,  6497.98941874, 11465.61187551, 18204.52978814,
#        13685.48097482, 10054.91072568, 19199.30211819, 10949.42303308,
#         6472.67275762,  7830.19665329, 11017.31922883, 12073.50203174,
#        10575.28285626, 13873.62911545,  8351.38005321,  6814.38033822,
#        17556.34269626, 10629.50197954,  9785.20724246,  9026.73506176,
#        13201.64559036,  6838.16648352, 14867.23051535, 13072.79810562,
#        10752.68549449,  6839.57631698,  8159.70091237,  8088.83383446,
#         6817.19861323,  8729.18109747,  5945.11486877, 11583.20961891,
#        11860.55360885, 10497.02318995, 11530.81001637, 12729.81704471,
#         7930.7170647 ,  9496.01039958,  6611.34595973, 10457.80187807,
#        16682.55424316, 12937.24864416,  8087.66234878, 12110.32085966,
#        15461.89160605,  9948.71695407, 13301.40737993,  7497.3634554 ,
#         8336.39144933, 11715.00288782, 11797.41702238,  8175.51294878,
#         8232.46641646, 18488.25451798, 18252.41624341,  8258.0232135 ,
#        14143.25064226,  8780.89451092, 13483.70574721,  9195.33463293,
#        10350.40261757,  9592.03191501, 13076.08231441,  9058.02274209,
#         9239.04753677, 12490.449966  ,  9336.93039729,  8137.53391879,
#        17293.0419485 ,  7395.19964118, 13879.9843063 , 10040.36989263,
#         8021.87137094, 20415.71756125,  7043.16264614, 10111.18361339,
#         9240.50197192, 10305.88073065, 17177.31875883,  8908.98003514,
#        11239.77903043,  9910.96675645, 19454.90968911, 11062.31095921,
#        12391.84815593, 12842.21029484, 10239.97870942, 13520.87639127,
#        15829.78773438, 10265.46440769,  8898.82843237,  7859.1434333 ,
#         9179.77669045, 17339.64075277, 10329.06509659, 12611.06938372,
#        11366.03821376, 12373.54527361,  7816.89176451, 13484.74036105,
#        10152.74330649,  6887.05464798, 10956.31513862, 14902.71176838,
#        10188.15248567,  9674.78510831,  7618.08832207,  8575.40856079,
#         7971.96328476,  9143.33135123,  8410.56001015, 15139.21857837,
#        11037.77789722,  8383.49153545, 19459.52987044,  9030.82192231,
#         9031.18664686, 15662.84599652,  9965.36476227, 10609.70741277,
#         9924.40452077,  8603.29217239,  8119.15555381, 10611.95472057,
#         8622.98515054, 12858.81582283, 16903.74307508, 10667.26202298,
#        11400.17338848,  9089.7076236 ,  7761.22067017, 15879.17668803,
#        12579.79553996,  9201.90081631,  9470.52822482, 16651.67652346,
#        16171.37288124,  6821.48472103,  9949.52026381,  8310.59857316,
#        10401.31292146, 12361.54770024, 10310.96791349,  7651.24282483,
#        17959.03230993,  7585.31932971,  7676.86142127,  5336.59998919,
#         9581.73357494, 12235.92619301, 13509.71694919, 15565.22657715,
#        11140.25411275,  9845.90572212, 12448.19496674, 10509.16295201,
#         8698.18738583,  6337.89970695, 13419.99932858,  8443.42256007,
#         8553.50732467,  7064.80172155,  7045.17654207, 16292.82985969,
#        19654.97158098, 10685.34588209,  8159.0523713 , 12089.55945162,
#         7586.43334086,  7683.80902765, 10673.78051518,  8425.43857369,
#        13458.49441214, 10627.08902659,  9959.91319277, 17453.40865155,
#        10708.7147316 , 10775.74793954,  8431.55728846, 10407.75823874,
#        10432.38397777, 14274.66902515,  6982.65673989,  9544.81047241,
#         7438.48088231,  7156.63097552,  8932.15859103, 13549.96683786,
#        11103.94295844,  9396.03412002,  6808.91572122,  9046.29401665,
#        -9679.27525819,  7732.3693309 , 11691.52304482, 12258.88976942,
#        10245.19060044,  9139.11938935,  8468.4482393 ,  8691.49681232,
#        12276.25217213, 10286.34149623, 16219.18389549,  9030.11258807,
#         9540.07553889, 16251.79364504,  8407.57949526,  9240.6316225 ,
#        20167.31896245, 10131.732176  , 15470.19580023,  8996.45347671,
#        16055.7934292 , 10028.40113329, 16529.74532773,  8504.07225439,
#         7610.60468199, 10372.37240875, 12033.57308865,  9931.42528143,
#        11270.73826214, 11881.27236035,  8746.70878725, 17466.95404709,
#        19932.50100581,  6558.01296883,  8497.04809592, 13099.21485462,
#         7442.48214292,  8925.30719049,  6857.7879675 , 11366.19778115,
#        10360.65111997, 10085.1256566 , 12676.18265357,  7376.61065872,
#         6792.2079738 , 11878.59021566,  9077.28121921, 19867.41755801,
#        12334.15404678,  8349.52811487, 10086.47562102, 11161.27810625,
#        13238.82826514,  6802.71648802,  7674.13430082, 12004.20977589,
#         8338.58819855, 10771.06245127, 11354.30622747, 11341.08719103,
#         8762.53942952, 10714.88565054,  8828.08538629,  8316.23507792,
#         8358.14762969,  9974.15987934,  8969.12763976, 10998.66865933,
#         7244.81371431, 11775.94804226, 11963.65390275, 10709.42689595,
#         9849.25271664,  8514.68779996, 11582.50731036,  9829.75605766,
#        11418.35904974,  8104.02918824,  7483.43013748,  8256.65211275,
#         4840.74783484,  7443.42068811,  8414.72639558,  8462.68241869,
#         8427.58879202,  9400.81475486,  9723.81373267,  9297.20987705,
#         7789.57280862, 10797.40083127,  8327.90749897,  8621.29995022,
#         8331.46105402,  7216.89280991, 11871.13621154, 13185.21836396,
#         8133.60490998,  9181.70627918,  8730.31805139, 19286.80666791,
#        10562.4675994 ,  6570.45429844, 11532.45399216,  8208.10739982,
#         7782.63402525,  8142.21603825, 16144.44956892,  7612.09678643,
#        10904.00953375, 17925.28253081,  7802.64413593,  9310.95693691,
#        11155.71072707, 13667.93877332,  7015.85353467,  5121.41803498,
#        12966.88378391, 10188.591012  , 12479.66907792,  8138.5556964 ,
#        10913.20580855,  9132.85183619, 10328.42024035, 13941.37121801,
#        11036.4774052 ,  7272.64877699,  8020.53394936,  9294.80148805,
#        12356.68706996, 13623.38217879,  8695.55313118,  9705.82190524,
#        13213.27765359, 13744.86498907,  7250.30750642, 12164.78825536,
#         7155.44135569,  9766.19567413, 15833.51767903,  6302.73026871,
#         9402.19100971, 20531.63092362,  8469.47672619,  7510.04222838,
#         8701.10750627,  8616.22231428,  8338.03639611,  8840.78977019,
#         6699.05474407, 15882.42034268,  7368.36397988, 10420.70084685,
#         9324.46622775,  9308.44867679,  6729.94695434, 10607.38593874,
#        14028.30690775,  6947.02790064,  6386.22638984, 10545.62940113,
#         8723.28005437, 10532.11873435,  6373.74228172,  7540.89435563,
#         9324.60972002,  9489.78750328,  7861.03744358,  9599.29496531,
#        10921.52366591,  9900.24341119,  8305.82758364,  9089.80253666,
#         7634.97096242,  8272.58372447, 11163.69092845, 11094.48503634,
#         7046.47178514,  9528.16474763,  8197.64933726,  7650.79861541,
#        16765.63178163, 20421.57252408,  5440.75420266,  8355.81358297,
#        11323.23054344,  9547.67033736,  7983.22365536])

# %%
#finding the Testing accuracy model

r2_score(y_test,yprdct)
# Out:
# 0.6550065853643856

# %%
trainprdct=model.predict(X_train)
r2_score(y_train,trainprdct)
# Out:
# 0.8809181804024534

# %%
#training accuracy plots
sns.regplot(y_train,trainprdct)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Price'>

# %%
#testing accuracy
sns.regplot(y_test,yprdct)
# Out:
# <AxesSubplot:xlabel='Price'>

# %%
plt.boxplot(x);

# %% [markdown]
# # now i am trying to improve accuracy by removing the outlier

# %%
Q1=np.percentile(carprice_df['KM'],25,interpolation='midpoint')
Q3=np.percentile(carprice_df['KM'],75,interpolation='midpoint')
IQR=Q3-Q1

lower=Q1-1.5*IQR
upper=Q3+1.5*IQR
lower,upper
new_df=carprice_df[(carprice_df.KM>lower)&(carprice_df.KM<upper)]

Q1=np.percentile(carprice_df['cc'],25,interpolation='midpoint')
Q3=np.percentile(carprice_df['cc'],75,interpolation='midpoint')
IQR=Q3-Q1

lower=Q1-1.5*IQR
upper=Q3+1.5*IQR
lower,upper

new_df=new_df[(new_df.cc>lower)&(new_df.cc<upper)]

Q1=np.percentile(carprice_df['Weight'],25,interpolation='midpoint')
Q3=np.percentile(carprice_df['Weight'],75,interpolation='midpoint')
IQR=Q3-Q1

lower=Q1-1.5*IQR
upper=Q3+1.5*IQR
lower,upper

new_df=new_df[(new_df.Weight>lower)&(new_df.Weight<upper)]

Q1=np.percentile(carprice_df['Quarterly_Tax'],25,interpolation='midpoint')
Q3=np.percentile(carprice_df['Quarterly_Tax'],75,interpolation='midpoint')
IQR=Q3-Q1

lower=Q1-1.5*IQR
upper=Q3+1.5*IQR
lower,upper

new_df=new_df[(new_df.Quarterly_Tax>lower)&(new_df.Quarterly_Tax<upper)]
new_df
# Out:
#         Id  Price  Age_08_04  Mfg_Month  Mfg_Year     KM Fuel_Type   HP  \
# 17      18  17950         24          9      2002  21716    Petrol  110
# 19      20  16950         30          3      2002  64359    Petrol  110
# 20      21  15950         30          3      2002  67660    Petrol  110
# 22      23  15950         28          5      2002  56349    Petrol  110
# 23      24  16950         28          5      2002  32220    Petrol  110
# ...    ...    ...        ...        ...       ...    ...       ...  ...
# 1430  1437   8450         80          1      1998  23000    Petrol   86
# 1431  1438   7500         69         12      1998  20544    Petrol   86
# 1432  1439  10845         72          9      1998  19000    Petrol   86
# 1433  1440   8500         71         10      1998  17016    Petrol   86
# 1434  1441   7250         70         11      1998  16916    Petrol   86
#
#       Met_Color  Color  Automatic    cc  Doors  Cylinders  Gears  \
# 17            1   Blue          0  1600      3          4      5
# 19            1   Grey          0  1600      3          4      5
# 20            1   Blue          0  1600      3          4      5
# 22            1  Black          0  1600      3          4      5
# 23            1  Black          0  1600      3          4      5
# ...         ...    ...        ...   ...    ...        ...    ...
# 1430          0   Blue          0  1300      3          4      5
# 1431          1   Blue          0  1300      3          4      5
# 1432          0   Grey          0  1300      3          4      5
# 1433          0   Blue          0  1300      3          4      5
# 1434          1   Grey          0  1300      3          4      5
#
#       Quarterly_Tax  Weight
# 17               85    1105
# 19               85    1105
# 20               85    1105
# 22               85    1120
# 23               85    1120
# ...             ...     ...
# 1430             69    1015
# 1431             69    1025
# 1432             69    1015
# 1433             69    1015
# 1434             69    1015
#
# [1166 rows x 17 columns]

# %% [markdown]
# carprice_df['KM']=carprice_df['KM'][~((carprice_df['KM']<(Q1-1.5*IQR))|(carprice_df["KM"]>(Q3+1.5*IQR)))]

# %%
y=new_df.iloc[:,1]
x=new_df.iloc[:,[2,5,7,11,12,14,15,16]]
x=StandardScaler().fit_transform(x)
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.3,random_state=0)

model=LinearRegression().fit(X_train,y_train)

ypred=model.predict(X_test)
print('Test Accuracy',r2_score(y_test,ypred))

ypred_train=model.predict(X_train)
print('Training Accuracy',r2_score(y_train,ypred_train))
# Out:
# Test Accuracy 0.8710871156568181
# Training Accuracy 0.8773443802253585

# %%
sns.regplot(y_train,ypred_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Price'>

# %%
sns.regplot(y_test,ypred)
# Out:
# <AxesSubplot:xlabel='Price'>

# %%
plt.boxplot(x);
